# %%
import os
import numpy as np
import pandas as pd

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from tensorflow.keras.models import Model
import tensorflow_addons as tfa

from sklearn.metrics import *
import scikitplot as skplt

from functools import partial
import albumentations as A
import matplotlib.pyplot as plt
import seaborn as sns

AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
data = pd.read_csv('D:/semester3/original_200/Folds.csv')
img_dir = 'D:/semester3/original_200/'
class_names = ['benign', 'malignant']

# %%
data
# Out:
#        fold  mag    grp                                           filename
# 0         1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 1         1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 2         1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 3         1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 4         1  100  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# ...     ...  ...    ...                                                ...
# 39540     5  400   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 39541     5  400   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 39542     5  400   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 39543     5  400   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 39544     5  400   test  BreaKHis_v1/histology_slides/breast/malignant/...
#
# [39545 rows x 4 columns]

# %%
data = data.loc[(data['mag'] == 200) & (data['fold']==1)]

# %%
data
# Out:
#       fold  mag    grp                                           filename
# 30       1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 31       1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 32       1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 33       1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 34       1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# ...    ...  ...    ...                                                ...
# 7839     1  200   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 7840     1  200   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 7841     1  200   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 7842     1  200   test  BreaKHis_v1/histology_slides/breast/malignant/...
# 7843     1  200   test  BreaKHis_v1/histology_slides/breast/malignant/...
#
# [2013 rows x 4 columns]

# %%
data = data.rename(columns={'filename':'path'})
data['label'] = data.path.apply(lambda x: x.split('/')[3])
data['label_int'] = data.label.apply(lambda x: class_names.index(x))
data['filename'] = data.path.apply(lambda x: x.split('/')[-1])
data.head(3)
# Out:
#     fold  mag    grp                                               path  \
# 30     1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 31     1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
# 32     1  200  train  BreaKHis_v1/histology_slides/breast/benign/SOB...
#
#      label  label_int                        filename
# 30  benign          0  SOB_B_A-14-22549AB-200-001.png
# 31  benign          0  SOB_B_A-14-22549AB-200-002.png
# 32  benign          0  SOB_B_A-14-22549AB-200-003.png

# %%
data.to_csv('D:/semester3/original_200/original_updated_fold_200_v2.csv')

# %%
original_data_updated_200 = pd.read_csv('D:/semester3/original_200/original_updated_fold_200_v2.csv')

# %%
ax = sns.displot(data=original_data_updated_200, x=original_data_updated_200['label'])
print('Count of Benign    : ', original_data_updated_200[original_data_updated_200.label == 'benign'].label.count())
print('Count of Malignant : ', original_data_updated_200[original_data_updated_200.label == 'malignant'].label.count())
# Out:
# Count of Benign    :  623
# Count of Malignant :  1390

# %%
test_df = original_data_updated_200.groupby('label').sample(frac=0.2)
train_df = original_data_updated_200.drop(test_df.index).reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# split training and validation set
valid_df = train_df.sample(frac=0.1)
train_df = train_df.drop(valid_df.index).reset_index(drop=True)
valid_df = valid_df.reset_index(drop=True)

test_df['set'] = 'test'
train_df['set'] = 'train'
valid_df['set'] = 'valid'
data_new = pd.concat([train_df,valid_df, test_df])
print(data_new)

# ax = sns.displot(data=data_new, x='label', col='set')

print('Training set')
print(train_df.label.value_counts())

print('\nValidation set')
print(valid_df.label.value_counts())

print('\nTest set')
print(test_df.label.value_counts())
# Out:
#      Unnamed: 0  fold  mag    grp  \
# 0            31     1  200  train
# 1            32     1  200  train
# 2            34     1  200  train
# 3            35     1  200  train
# 4            37     1  200  train
# ..          ...   ...  ...    ...
# 398        1628     1  200  train
# 399        7361     1  200   test
# 400        7623     1  200   test
# 401        2102     1  200  train
# 402        4510     1  200  train
#
#                                                   path      label  label_int  \
# 0    BreaKHis_v1/histology_slides/breast/benign/SOB...     benign          0
# 1    BreaKHis_v1/histology_slides/breast/benign/SOB...     benign          0
# 2    BreaKHis_v1/histology_slides/breast/benign/SOB...     benign          0
# 3    BreaKHis_v1/histology_slides/breast/benign/SOB...     benign          0
# 4    BreaKHis_v1/histology_slides/breast/benign/SOB...     benign          0
# ..                                                 ...        ...        ...
# 398  BreaKHis_v1/histology_slides/breast/malignant/...  malignant          1
# 399  BreaKHis_v1/histology_slides/breast/malignant/...  malignant          1
# 400  BreaKHis_v1/histology_slides/breast/malignant/...  malignant          1
# 401  BreaKHis_v1/histology_slides/breast/malignant/...  malignant          1
# 402  BreaKHis_v1/histology_slides/breast/malignant/...  malignant          1
#
#                            filename    set
# 0    SOB_B_A-14-22549AB-200-002.png  train
# 1    SOB_B_A-14-22549AB-200-003.png  train
# 2    SOB_B_A-14-22549AB-200-005.png  train
# 3    SOB_B_A-14-22549AB-200-006.png  train
# 4    SOB_B_A-14-22549AB-200-008.png  train
# ..                              ...    ...
# 398   SOB_M_DC-14-12312-200-017.png   test
# 399   SOB_M_LC-14-15570-200-034.png   test
# 400  SOB_M_MC-14-18842D-200-014.png   test
# 401   SOB_M_DC-14-14926-200-004.png   test
# 402   SOB_M_MC-14-18842-200-015.png   test
#
# [2013 rows x 9 columns]
# Training set
# malignant    997
# benign       452
# Name: label, dtype: int64
#
# Validation set
# malignant    115
# benign        46
# Name: label, dtype: int64
#
# Test set
# malignant    278
# benign       125
# Name: label, dtype: int64

# %%
print(train_df.label.value_counts())
# Out:
# malignant    997
# benign       452
# Name: label, dtype: int64

# %%
# upsampling training dataset
max_count = np.max(train_df.label.value_counts())
min_count = np.min(train_df.label.value_counts())
train_df = train_df.groupby('label').sample(n=max_count, replace=True)
train_df = train_df.reset_index(drop=True)
train_df.label.value_counts()

ax = sns.displot(data=train_df, x=train_df['label'])

# %%
train_loader = tf.data.Dataset.from_tensor_slices((img_dir+train_df.path, train_df.label_int))
valid_loader = tf.data.Dataset.from_tensor_slices((img_dir+valid_df.path, valid_df.label_int))
test_loader=tf.data.Dataset.from_tensor_slices((img_dir+test_df.path, test_df.label_int))

# %%
model_handle_map = {

 "efficientnet_b0": "https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1"

}


model_image_size_map = {

 "efficientnet_b0": 224

}

# %%
model_name = 'efficientnet_b0'
model_handle = model_handle_map.get(model_name)
IMAGE_SIZE = model_image_size_map.get(model_name, 224)
BATCH_SIZE = 64
EPOCHS = 12
SAMPLE_SIZE = len(train_df)

print(f"Selected model: {model_name} : {model_handle}")
print(f"Input size {IMAGE_SIZE}")
# Out:
# Selected model: efficientnet_b0 : https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1
# Input size 224

# %%
def parse_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels=3)
    return img, label

# %%
def resize_rescale(image, label):
    img = tf.cast(image, tf.float32)
    img = tf.image.resize(img, [IMAGE_SIZE, IMAGE_SIZE])/255
    return img, label

# %%
train_loader = tf.data.Dataset.from_tensor_slices((img_dir+train_df.path, train_df.label_int))
valid_loader = tf.data.Dataset.from_tensor_slices((img_dir+valid_df.path, valid_df.label_int))

train_ds = (
    train_loader.shuffle(len(train_df))
    .map(parse_image, num_parallel_calls=AUTOTUNE)
#     .map(partial(augmentor),num_parallel_calls=AUTOTUNE)
    .map(resize_rescale, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE) 
)
valid_ds = (
    valid_loader.shuffle(len(valid_df))
    .map(parse_image, num_parallel_calls=AUTOTUNE)
    .map(resize_rescale, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

# %%
def view_image(ds, col=8, row=2, size=(25,7)):
    plt.figure(figsize=size)
    plt.subplots_adjust(wspace=0.05, hspace=0.15)
    for images, labels in ds.take(1):
        for i in range(col*row):
            ax = plt.subplot(row, col, i + 1)
            shape = str(images[i].numpy().shape)
            plt.imshow(images[i].numpy())
            plt.title(class_names[labels[i].numpy()])
            plt.axis("off") 
    plt.tight_layout
    return None

# %%
view_image(train_ds)

# %%
def build_network(image_size):
    print('building model...')
    model = tf.keras.Sequential([
        layers.InputLayer(input_shape=(image_size, image_size, 3)),
        hub.KerasLayer(model_handle, trainable=True, name='base_model'),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dense(1, activation='sigmoid', name='classifier') 
    ],name=model_name)
    model.build((None, image_size, image_size, 3))
    model.summary()
    print('model loaded!!!')
    return model

# %%
tf.keras.backend.clear_session()
model = build_network(IMAGE_SIZE)
# Out:
# building model...
# Model: "efficientnet_b0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  base_model (KerasLayer)     (None, 1280)              4049564
#
#  dense (Dense)               (None, 512)               655872
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  classifier (Dense)          (None, 1)                 129
#
# =================================================================
# Total params: 4,773,789
# Trainable params: 4,730,493
# Non-trainable params: 43,296
# _________________________________________________________________
# model loaded!!!

# %%
#checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("best_model_40.h5", save_best_only=True)
checkpoint_cb = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',min_delta = 0,patience = 3, verbose = 1,restore_best_weights = True)
clr_scheduler = tfa.optimizers.CyclicalLearningRate( 
    initial_learning_rate=2e-05,  maximal_learning_rate=7e-3, 
    step_size=3*(SAMPLE_SIZE//BATCH_SIZE),  
    scale_fn=lambda x: 1 / (2.0 ** (x - 1)), 
    scale_mode='cycle'
)
METRICS = [
    'accuracy',
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),

]

model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=clr_scheduler) , 
    loss=tf.keras.losses.BinaryCrossentropy(), 
    metrics=METRICS
)

history = model.fit(
    train_ds, 
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    callbacks = [checkpoint_cb],
    validation_data=valid_ds,
)
# Out:
# Epoch 1/12
# 32/32 [==============================] - 543s 16s/step - loss: 0.9561 - accuracy: 0.5306 - precision: 0.5300 - recall: 0.5406 - auc: 0.5353 - val_loss: 0.9070 - val_accuracy: 0.3230 - val_precision: 0.6667 - val_recall: 0.1043 - val_auc: 0.4875
# Epoch 2/12
# 32/32 [==============================] - 900s 28s/step - loss: 0.8263 - accuracy: 0.6123 - precision: 0.6127 - recall: 0.6108 - auc: 0.6595 - val_loss: 0.8472 - val_accuracy: 0.4969 - val_precision: 0.8269 - val_recall: 0.3739 - val_auc: 0.6122
# Epoch 3/12
# 32/32 [==============================] - 1218s 39s/step - loss: 0.6501 - accuracy: 0.7452 - precision: 0.7428 - recall: 0.7503 - auc: 0.8242 - val_loss: 0.7611 - val_accuracy: 0.6894 - val_precision: 0.8571 - val_recall: 0.6783 - val_auc: 0.7707
# Epoch 4/12
# 32/32 [==============================] - 772s 24s/step - loss: 0.5089 - accuracy: 0.8475 - precision: 0.8291 - recall: 0.8756 - auc: 0.9173 - val_loss: 0.6791 - val_accuracy: 0.8075 - val_precision: 0.8962 - val_recall: 0.8261 - val_auc: 0.8489
# Epoch 5/12
# 32/32 [==============================] - 837s 26s/step - loss: 0.4634 - accuracy: 0.8621 - precision: 0.8485 - recall: 0.8816 - auc: 0.9373 - val_loss: 0.6177 - val_accuracy: 0.8323 - val_precision: 0.9000 - val_recall: 0.8609 - val_auc: 0.8842
# Epoch 6/12
# 32/32 [==============================] - 885s 28s/step - loss: 0.4304 - accuracy: 0.8892 - precision: 0.8760 - recall: 0.9067 - auc: 0.9536 - val_loss: 0.5759 - val_accuracy: 0.8509 - val_precision: 0.8957 - val_recall: 0.8957 - val_auc: 0.8959
# Epoch 7/12
# 32/32 [==============================] - 918s 29s/step - loss: 0.4192 - accuracy: 0.8806 - precision: 0.8646 - recall: 0.9027 - auc: 0.9582 - val_loss: 0.5439 - val_accuracy: 0.8509 - val_precision: 0.8824 - val_recall: 0.9130 - val_auc: 0.8986
# Epoch 8/12
# 32/32 [==============================] - 920s 29s/step - loss: 0.4107 - accuracy: 0.8872 - precision: 0.8697 - recall: 0.9107 - auc: 0.9606 - val_loss: 0.5150 - val_accuracy: 0.8447 - val_precision: 0.8879 - val_recall: 0.8957 - val_auc: 0.9009
# Epoch 9/12
# 32/32 [==============================] - 920s 29s/step - loss: 0.3926 - accuracy: 0.8997 - precision: 0.8821 - recall: 0.9228 - auc: 0.9650 - val_loss: 0.4832 - val_accuracy: 0.8447 - val_precision: 0.8814 - val_recall: 0.9043 - val_auc: 0.9098
# Epoch 10/12
# 32/32 [==============================] - 984s 31s/step - loss: 0.3681 - accuracy: 0.9173 - precision: 0.8992 - recall: 0.9398 - auc: 0.9732 - val_loss: 0.4632 - val_accuracy: 0.8447 - val_precision: 0.8814 - val_recall: 0.9043 - val_auc: 0.9171
# Epoch 11/12
# 32/32 [==============================] - 974s 30s/step - loss: 0.3673 - accuracy: 0.9132 - precision: 0.8977 - recall: 0.9328 - auc: 0.9723 - val_loss: 0.4530 - val_accuracy: 0.8509 - val_precision: 0.8889 - val_recall: 0.9043 - val_auc: 0.9200
# Epoch 12/12
# 32/32 [==============================] - 1010s 32s/step - loss: 0.3555 - accuracy: 0.9233 - precision: 0.9050 - recall: 0.9458 - auc: 0.9756 - val_loss: 0.4478 - val_accuracy: 0.8447 - val_precision: 0.8879 - val_recall: 0.8957 - val_auc: 0.9207

# %%
def training_history(history):
    accuracy = history['accuracy']
    val_accuracy = history['val_accuracy']

    loss = history['loss']
    val_loss = history['val_loss']

    epochs_range = range(len(history['loss']))

    plt.figure(figsize=(16, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, accuracy, label='Training accuracy')
    plt.plot(epochs_range, val_accuracy, label='Validation accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.show()
    return None

# %%
training_history(history.history)

# %%
def decode_test(path):
    img = tf.io.read_file(path)
    img = tf.image.decode_png(img, channels=3)
    img = tf.cast(img, tf.float32)
    img = tf.image.resize(img, [224, 224])/255
    return img

# %%
test_df = test_df.reset_index(drop=True)
test_ds = tf.data.Dataset.from_tensor_slices(img_dir+test_df.path) 
test_ds = test_ds.map(decode_test,num_parallel_calls=AUTOTUNE).batch(len(test_df))
test_img = next(iter(test_ds))
test_index = test_df.label_int.values
test_label = test_df.label.values

test_pred = model.predict(test_ds)
pred_index = np.round(test_pred).astype('uint8')
pred_label = np.array(class_names)[pred_index]

print(classification_report(test_index, pred_index, target_names=class_names,zero_division=0))
print('f1_score        :', f1_score(test_index, pred_index, average='micro'))
print('accuracy_score  :', accuracy_score(test_index, pred_index))
print('precision_score  :', precision_score(test_index, pred_index))
print('recall_score  :', recall_score(test_index, pred_index))

cm = skplt.metrics.plot_confusion_matrix(test_label, pred_label, figsize=(8, 8), normalize=False,cmap="OrRd")
# Out:
# 1/1 [==============================] - 11s 11s/step
#               precision    recall  f1-score   support
#
#       benign       0.81      0.81      0.81       125
#    malignant       0.91      0.92      0.92       278
#
#     accuracy                           0.88       403
#    macro avg       0.86      0.86      0.86       403
# weighted avg       0.88      0.88      0.88       403
#
# f1_score        : 0.8833746898263027
# accuracy_score  : 0.8833746898263027
# precision_score  : 0.9139784946236559
# recall_score  : 0.9172661870503597

# %%
print('f1_score        :', f1_score(test_index, pred_index))
# Out:
# f1_score        : 0.9156193895870736

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('model recall')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('model precision')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('model auc')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
#plt.plot(history.history['f1_score'])
#plt.plot(history.history['val_f1_score'])
#plt.title('model f1_score')
#plt.legend(['train', 'val'], loc='upper left')
#plt.show()
